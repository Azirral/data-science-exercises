# %% [markdown]
# # Assignment 2

# %% [markdown]
# Answer questions 1-4 using the network `G1`, a network of friendships at a university department. Each node corresponds to a person, and an edge indicates friendship.
#
# *The network has been loaded as networkx graph object `G1`.*

# %%
# %matplotlib inline
import networkx as nx

G1 = nx.read_gml('friendships.gml')
nx.draw(G1)

# %% [markdown]
# ### Question 1 (3 pkt)
#
# Find the degree centrality, closeness centrality, and normalized betweeness centrality (excluding endpoints) of node 100.

# %%
n = 100

degree_centrality = nx.degree_centrality(G1)[n]
closeness_centrality = nx.closeness_centrality(G1)[n]
betweenness_centrality = nx.betweenness_centrality(G1)[n]

print(degree_centrality)
print(closeness_centrality)
print(betweenness_centrality)
# Out:
# 0.0026501766784452294
# 0.2654784240150094
# 7.142902633244772e-05

# %% [markdown]
# <br>
# #### For Questions 2, 3, and 4, use one of the covered centrality measures to rank the nodes and find the most appropriate candidate.
# <br>

# %% [markdown]
# ### Question 2 (1 pkt)
#
# Suppose you are employed by an online shopping website and are tasked with selecting one user in network G1 to send an online shopping voucher to. We expect that the user who receives the voucher will send it to their friends in the network.  You want the voucher to reach as many nodes as possible. The voucher can be forwarded to multiple users at the same time, but the travel distance of the voucher is limited to one step, which means if the voucher travels more than one step in this network, it is no longer valid. Apply your knowledge in network centrality to select the best candidate for the voucher.

# %%
import networkx as nx

degree_centrality = nx.degree_centrality(G1)

best = max(degree_centrality, key=degree_centrality.get)

print(best)
print(degree_centrality[best])
# Out:
# 105
# 0.0636042402826855

# %% [markdown]
# ### Question 3 (1 pkt)
#
# Now the limit of the voucher’s travel distance has been removed. Because the network is connected, regardless of who you pick, every node in the network will eventually receive the voucher. However, we now want to ensure that the voucher reaches the nodes in the lowest average number of hops.
#
# How would you change your selection strategy? Write a function to tell us who is the best candidate in the network under this condition.

# %%
closeness_centrality = nx.closeness_centrality(G1)

best = max(closeness_centrality, key=closeness_centrality.get)

print(best)
print(closeness_centrality[best])
# Out:
# 23
# 0.3847722637661455

# %% [markdown]
# ### Question 4 (1 pkt)
#
# Assume the restriction on the voucher’s travel distance is still removed, but now a competitor has developed a strategy to remove a person from the network in order to disrupt the distribution of your company’s voucher. Identify the single riskiest person to be removed under your competitor’s strategy?

# %%
betweenness_centrality = nx.betweenness_centrality(G1)

best = max(betweenness_centrality, key=betweenness_centrality.get)

print(best)
print(betweenness_centrality[best])
# Out:
# 333
# 0.03939111019601939
